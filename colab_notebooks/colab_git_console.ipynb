# %% [markdown]
# <a href="https://colab.research.google.com/github/DarioRugg/Self-Supervised_Pearson_Search/blob/pretrained_test/main_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Path

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Università/Data Science/Second Year/Second Semester/Path of Excellence/Code/Self-Supervised_Pearson_Search/
# Out:
# /content/drive/My Drive/Università/Data Science/Second Year/Second Semester/Path of Excellence/Code/Self-Supervised_Pearson_Search

# %% [markdown]
# ## Git pull
# Get last modifications

# %%
# !git pull
# Out:
# Already up to date.

# %% [markdown]
# ## Git push

# %%
# !git add .
# !git commit -m "added notebook for managing files"
# !git push
# Out:
# warning: adding embedded git repository: self_supervision/JigsawPuzzlePytorch
# hint: You've added another git repository inside your current repository.
# hint: Clones of the outer repository will not contain the contents of
# hint: the embedded repository and will not know how to obtain it.
# hint: If you meant to add a submodule, use:
# hint:
# hint: 	git submodule add <url> self_supervision/JigsawPuzzlePytorch
# hint:
# hint: If you added this path by mistake, you can remove it from the
# hint: index with:
# hint:
# hint: 	git rm --cached self_supervision/JigsawPuzzlePytorch
# hint:
# hint: See "git help submodule" for more information.
# [pretrained_test 57f9e79] added notebook for managing files
#  13 files changed, 4982 insertions(+), 55 deletions(-)
#  create mode 100644 colab_notebooks/actual_model_trainign.ipynb
#  create mode 100644 colab_notebooks/clone_VISSL.ipynb
#  create mode 100644 colab_notebooks/colab_git_console.ipynb
#  rename moving_files.ipynb => colab_notebooks/handling_files_on_drive.ipynb (100%)
#  create mode 100644 colab_notebooks/no_vissl_self-supervised_backbone_trainign.ipynb
#  create mode 100644 colab_notebooks/self-supervised_backbone_trainign.ipynb
#  create mode 100644 colab_notebooks/self-supervised_backbone_trainign_cd_to_vissl.ipynb
#  create mode 100644 colab_notebooks/visualize images.ipynb
#  rewrite configs/config/dataset_catalog.json (100%)
#  delete mode 100644 main_notebook.ipynb
#  create mode 160000 self_supervision/JigsawPuzzlePytorch
# Counting objects: 16, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (15/15), done.
# Writing objects: 100% (16/16), 196.07 KiB | 4.17 MiB/s, done.
# Total 16 (delta 6), reused 0 (delta 0)
# remote: Resolving deltas: 100% (6/6), completed with 2 local objects.
# To https://github.com/DarioRugg/Self-Supervised_Pearson_Search.git
#    ab453d1..57f9e79  pretrained_test -> pretrained_test

# %%
# %cd self_supervision/JigsawPuzzlePytorch/
# Out:
# /content/drive/My Drive/Università/Data Science/Second Year/Second Semester/Path of Excellence/Code/Self-Supervised_Pearson_Search/self_supervision/JigsawPuzzlePytorch

# %%
# !rm -rf .git
