# %% [markdown]
# <a href="https://colab.research.google.com/github/DarioRugg/Self-Supervised_Pearson_Search/blob/pretrained_test/main_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Path

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Università/Data Science/Second Year/Second Semester/Path of Excellence/Code/Self-Supervised_Pearson_Search/
# Out:
# /content/drive/My Drive/Università/Data Science/Second Year/Second Semester/Path of Excellence/Code/Self-Supervised_Pearson_Search

# %% [markdown]
# ## Git pull
# Get last modifications

# %%
# !git pull
# Out:
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 2 (delta 1), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (2/2), done.
# From https://github.com/DarioRugg/Self-Supervised_Pearson_Search
#    26eb9ad..e949a87  pretrained_test -> origin/pretrained_test
# Updating 26eb9ad..e949a87
# ...
# Fast-forward
#  self_supervision/JigsawPuzzlePytorch | 1 -
#  1 file changed, 1 deletion(-)
#  delete mode 160000 self_supervision/JigsawPuzzlePytorch

# %% [markdown]
# ## Git push

# %%
# !git add .
# !git commit -m "try to add the repo"
# !git push
# Out:
# [pretrained_test 26eb9ad] try to add the repo
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite colab_notebooks/colab_git_console.ipynb (81%)
#  rewrite colab_notebooks/no_vissl_self-supervised_backbone_trainign.ipynb (89%)
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 1.31 KiB | 334.00 KiB/s, done.
# Total 5 (delta 4), reused 0 (delta 0)
# remote: Resolving deltas: 100% (4/4), completed with 4 local objects.
# To https://github.com/DarioRugg/Self-Supervised_Pearson_Search.git
#    9df3627..26eb9ad  pretrained_test -> pretrained_test

# %%
ls
# Out:
# colab_notebooks/  lib/       run_distributed_engines.py
# configs/          LICENSE    scripts/
# data@             log.txt    self_supervision/
# environment.yml   README.md

# %%
# !git branch
# Out:
#   main
# * pretrained_test

# %%
# %cd self_supervision/JigsawPuzzlePytorch/
# Out:
# /content/drive/MyDrive/Università/Data Science/Second Year/Second Semester/Path of Excellence/Code/Self-Supervised_Pearson_Search/self_supervision/JigsawPuzzlePytorch

# %% [markdown]
# back to root

# %%
# %cd /content/drive/MyDrive/Università/Data Science/Second Year/Second Semester/Path of Excellence/Code/Self-Supervised_Pearson_Search/
# Out:
# /content/drive/MyDrive/Università/Data Science/Second Year/Second Semester/Path of Excellence/Code/Self-Supervised_Pearson_Search
